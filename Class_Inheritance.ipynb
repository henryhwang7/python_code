# %%
import random
import time
class Person:
    Name = ""
    age = 0
    Type = ""
    
    def __init__(self):
        self.Setperson()
    def SetPerson(self):
        self.Name = input("Name: ")
        self.age = int(input("Age: "))
        self.Type = input("Gender: ")
    def ShowPerson(self):
        print("""Name: {0}
        Age: {1}
        Gender: {2}""".format(self.Name,self.age,self.Type))
    def work(self):
        print("{0} is working".format(self.Name))
        for i in range(3):
            print(".")
            time.sleep(1)
    def Sleep(self):
        print("{0} is sleeping.".format(self.Name))
        for i in range(5):
            print(".")
            time.sleep(1)
    def Meal(self):
        print("{0} is eating.".format(self.Name))
        for i in range(4):
            print(".")
            time.sleep(1)

class OfficeWorker(Person):
    pay = 0
    position = ""
    balance = 0
    stamina = 100
    
    def __init__(self):
        self.SetPerson()
        self.SetWorker()
        
    def SetWorker(self):
        self.pay = int(input("Type your monthly salary: "))
        self.level = input("Your level: ")
        self.balance += self.pay
        self.stamina
        
    def work(self):
        print("{0} is currently working...".format(self.Name))
        self.stamina -= 50
        for i in range(3):
            print(".")
            time.sleep(1)
    
    def holiday(self):
        print("{0} is currently on vacation...".format(self.Name))
        self.stamina += 20
        for i in range(2):
            print(".")
            time.sleep(1)
    
    def payday(self):
        print("{0} is getting payed {1} dollars for month salary".format(self.Name,self.pay))
        print("Current bank balance is {0} dollars".format(self.wallet))
        self.stamina += 30
        for i in range(2):
            print(".")
            time.sleep(1)
            
    def ShowWorker(self):
        print("{0} worker's current stamina is {1}".format(self.Name,self.stamina))
        print("{0} worker's current bank balance is {1}".format(self.Name, self.balance))
        print("{0} worker's current monthly salary is {1}".format(self.Name, self.pay))
        print("{0} worker's current job position is {1}".format(self.Name, self.position))
        print("{0} worker's age : {1}".format(self.Name, self.age))
        print("{0} worker's gender : {1}".format(self.Name, self.Type))
